# %%
# !pip install jupyterthemes
# !jt -t onedork -fs 115 -nfs 125 -tfs 115 -dfs 115 -ofs 115 -cursc r -cellw 80% -lineh 115 -altmd  -kl -T -N

# %%
import pandas as pd

# %%
c_df = pd.read_csv('bank3_customers.csv', index_col = 'c_id')
c_df
# Out:
#       name  account_num  total_amount     rat
# c_id
# 1c     최원칠            2           500  silver
# 2c     이서혁            1          2000    gold
# 3c    aiot            3         50000     vip
# 4c      새싹            4        200000    vvip

# %%
c_id = '1c'
c_df.loc[c_id] = self.

# %%
c_df.set_index('c_id', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 c_df.set_index('c_id', inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:6001, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5998                 missing.append(col)
#    6000 if missing:
# -> 6001     raise KeyError(f"None of {missing} are in the columns")
#    6003 if inplace:
#    6004     frame = self
#
# KeyError: "None of ['c_id'] are in the columns"

# %%
c_df.index
# Out:
# Index(['1c', '2c', '3c', '4c'], dtype='object', name='c_id')

# %%
for c in c_df.index:
    print(type(c_df.loc[c]))
    print(c_df.loc[c])
    print('='*50)
# Out:
# <class 'pandas.core.series.Series'>
# name               최원칠
# account_num          2
# total_amount       500
# rat             silver
# Name: 1c, dtype: object
# ==================================================
# <class 'pandas.core.series.Series'>
# name             이서혁
# account_num        1
# total_amount    2000
# rat             gold
# Name: 2c, dtype: object
# ==================================================
# <class 'pandas.core.series.Series'>
# name             aiot
# account_num         3
# total_amount    50000
# rat               vip
# Name: 3c, dtype: object
# ==================================================
# <class 'pandas.core.series.Series'>
# name                새싹
# account_num          4
# total_amount    200000
# rat               vvip
# Name: 4c, dtype: object
# ==================================================

# %%
c_df = pd.read_csv('bank3_customers.csv')
c_df.loc[c_df['c_id'] == '99c']
# Out:
# Empty DataFrame
# Columns: [c_id, name, account_num, total_amount, rat]
# Index: []

# %%
c_name = input('고객 이름 입력:')
c_id = input('고객 번호 입력:')
customer = {'c_id': c_id,
                'name': c_name,
                'account_num': 0,
                'total_amount': 0,
                'rat': 'normal'
                }
c_df.loc[c_id] = customer
c_df
# Out:
# 고객 이름 입력:123
# 고객 번호 입력:123
#     c_id  name  account_num  total_amount     rat
# 0     1c   최원칠            2           500  silver
# 1     2c   이서혁            1          2000    gold
# 2     3c  aiot            3         50000     vip
# 3     4c    새싹            4        200000    vvip
# 123  123   123            0             0  normal

# %%
c_df.loc[c_df['c_id'] == customer['c_id']]
# Out:
#     c_id name  account_num  total_amount     rat
# 123  123  123            0             0  normal

# %%
c_df['account_num'].loc['1c'] += 1
c_df
# Out:
# C:\Users\YUNA\AppData\Local\Temp\ipykernel_1792\1293716862.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_df['account_num'].loc['1c'] += 1
#       name  account_num  total_amount     rat
# c_id
# 1c     최원칠            3           500  silver
# 2c     이서혁            1          2000    gold
# 3c    aiot            3         50000     vip
# 4c      새싹            4        200000    vvip

# %%
a_df = pd.read_csv('bank3_accounts.csv')
a_df.set_index('c_id', drop = False, inplace=True)
a_df
# Out:
#      a_id password c_id  amount
# c_id
# 1c    11a      11p   1c     100
# 1c    12a      12p   1c     400
# 2c    21a      21p   2c    2000
# 3c    31a      31p   3c   10000
# 3c    32a      32p   3c   20000
# 3c    33a      33p   3c   20000
# 4c    41a      41p   4c  100000
# 4c    42a      42p   4c   50000
# 4c    43a      43p   4c   20000
# 4c    44a      44p   4c   30000

# %%
a_df = pd.read_csv('bank3_accounts.csv', index_col = 'a_id')
a_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [89], line 1
# ----> 1 a_df = pd.read_csv('bank3_accounts.csv', index_col = 'a_id', drop=False)
#       2 a_df
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# TypeError: read_csv() got an unexpected keyword argument 'drop'

# %%
a_id = '13a'
a_dict = {'a_id': a_id, 'password': None, 'c_id': None, 'amount': 0}
a_df = a_df.append(a_dict, ignore_index=True)
a_df
# Out:
# C:\Users\SBAUser\AppData\Local\Temp\ipykernel_13444\2794025448.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a_df = a_df.append(a_dict, ignore_index=True)
#    password  c_id  amount a_id
# 0       11p    1c     100  NaN
# 1       12p    1c     400  NaN
# 2       21p    2c    2000  NaN
# 3       31p    3c   10000  NaN
# 4       32p    3c   20000  NaN
# 5       33p    3c   20000  NaN
# 6       41p    4c  100000  NaN
# 7       42p    4c   50000  NaN
# 8       43p    4c   20000  NaN
# 9       44p    4c   30000  NaN
# 10     None  None       0  13a
# 11     None  None       0  13a
# 12     None  None       0  13a

# %%
a_id = '13a'
a_dict = {'a_id': a_id, 'password': None, 'c_id': None, 'amount': 0}
# a = pd.Series.to_frame(a_dict, 'a_id')
a = pd.DataFrame([a_dict])
a.set_index('a_id', inplace=True)
a
# Out:
#      password  c_id  amount
# a_id
# 13a      None  None       0

# %%
a_df.append(a)
# Out:
# C:\Users\SBAUser\AppData\Local\Temp\ipykernel_13444\3484369687.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a_df.append(a)
#      password  c_id  amount
# a_id
# 11a       11p    1c     100
# 12a       12p    1c     400
# 21a       21p    2c    2000
# 31a       31p    3c   10000
# 32a       32p    3c   20000
# 33a       33p    3c   20000
# 41a       41p    4c  100000
# 42a       42p    4c   50000
# 43a       43p    4c   20000
# 44a       44p    4c   30000
# 13a      None  None       0

# %%
a_df['amount'].loc[a_id] += amount

# %%
# self.accounts 에서 해당 계좌번호의 계좌금액에서 입금금액 추가
a_df['amount'].loc['11a'] +500
# Out:
# 600

# %%
# Out:
# C:\Users\SBAUser\AppData\Local\Temp\ipykernel_13444\790866824.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a_df.append(a, ignore_index=True)
#   a_id password c_id  amount
# 0  11a      11a  11a     11a
# 1  12a      12p   1c     400
# 2  21a      21p   2c    2000
# 3  31a      31p   3c   10000
# 4  32a      32p   3c   20000
# 5  33a      33p   3c   20000
# 6  41a      41p   4c  100000
# 7  42a      42p   4c   50000
# 8  43a      43p   4c   20000
# 9  44a      44p   4c   30000

# %%
a_df['a_id']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 a_df['a_id']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'a_id'

# %%
a_df.loc[a_df['a_id'] == a['a_id']] = a['a_id']
a_df
# Out:
#   a_id password c_id  amount
# 0  11a      11a  11a     11a
# 1  12a      12p   1c     400
# 2  21a      21p   2c    2000
# 3  31a      31p   3c   10000
# 4  32a      32p   3c   20000
# 5  33a      33p   3c   20000
# 6  41a      41p   4c  100000
# 7  42a      42p   4c   50000
# 8  43a      43p   4c   20000
# 9  44a      44p   4c   30000

# %%
df_accounts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   a_id      10 non-null     object
#  1   password  10 non-null     object
#  2   c_id      10 non-null     object
#  3   amount    10 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 448.0+ bytes

# %%
df_accounts[['a_id', 'amount']]
# Out:
#   a_id  amount
# 0  11a     100
# 1  12a     400
# 2  21a    2000
# 3  31a   10000
# 4  32a   20000
# 5  33a   20000
# 6  41a  100000
# 7  42a   50000
# 8  43a   20000
# 9  44a   30000

# %%
df_accounts[['a_id', 'amount']][df_accounts['a_id'] == '32a']
# Out:
#   a_id  amount
# 4  32a   20000

# %%
df_accounts.loc['32a':]
# Out:
#   a_id password c_id  amount
# 4  32a      32p   3c   20000
# 5  33a      33p   3c   20000
# 6  41a      41p   4c  100000
# 7  42a      42p   4c   50000
# 8  43a      43p   4c   20000
# 9  44a      44p   4c   30000
