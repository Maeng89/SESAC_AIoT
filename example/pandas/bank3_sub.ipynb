# %%
# !pip install jupyterthemes
# !jt -t onedork -fs 115 -nfs 125 -tfs 115 -dfs 115 -ofs 115 -cursc r -cellw 80% -lineh 115 -altmd  -kl -T -N

# %%
import pandas as pd

# %%
c_df = pd.read_csv('bank3_customers.csv', index_col = 'c_id')
c_df
# Out:
#       name  account_num  total_amount     rat
# c_id
# 1c     최원칠            2           500  silver
# 2c     이서혁            1          2000    gold
# 3c    aiot            3         50000     vip
# 4c      새싹            4        200000    vvip

# %%
c_df.set_index('c_id', inplace=True)
# Out:
#       name  account_num  total_amount     rat
# c_id
# 1c     최원칠            2           500  silver
# 2c     이서혁            1          2000    gold
# 3c    aiot            3         50000     vip
# 4c      새싹            4        200000    vvip

# %%
c_df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
for c in c_df.index:
    print(type(c_df.loc[c]))
    print(c_df.loc[c])
    print('='*50)
# Out:
# <class 'pandas.core.series.Series'>
# c_id                1c
# name               최원칠
# account_num          2
# total_amount       500
# rat             silver
# Name: 0, dtype: object
# ...
# <class 'pandas.core.series.Series'>
# c_id              2c
# name             이서혁
# account_num        1
# total_amount    2000
# rat             gold
# Name: 1, dtype: object
# ...
# <class 'pandas.core.series.Series'>
# c_id               3c
# name             aiot
# account_num         3
# total_amount    50000
# rat               vip
# Name: 2, dtype: object
# ...
# <class 'pandas.core.series.Series'>
# c_id                4c
# name                새싹
# account_num          4
# total_amount    200000
# rat               vvip
# Name: 3, dtype: object
# ...

# %%
c_df = pd.read_csv('bank3_customers.csv')
c_df.loc[c_df['c_id'] == '1c']
# Out:
#   c_id name  account_num  total_amount     rat
# 0   1c  최원칠            2           500  silver

# %%
c_name = input('고객 이름 입력:')
c_id = input('고객 번호 입력:')
customer = {'c_id': c_id,
                'name': c_name,
                'account_num': 0,
                'total_amount': 0,
                'rat': 'normal'
                }
c_df.loc[c_df['c_id'] == c_id] = customer
c_df
# Out:
# 고객 이름 입력:qwe
# 고객 번호 입력:123
#   c_id  name  account_num  total_amount     rat
# 0   1c   최원칠            2           500  silver
# 1   2c   이서혁            1          2000    gold
# 2   3c  aiot            3         50000     vip
# 3   4c    새싹            4        200000    vvip

# %%
c_df['account_num'].loc['1c'] += 1
c_df
# Out:
# C:\Users\YUNA\AppData\Local\Temp\ipykernel_1792\1293716862.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_df['account_num'].loc['1c'] += 1
#       name  account_num  total_amount     rat
# c_id
# 1c     최원칠            3           500  silver
# 2c     이서혁            1          2000    gold
# 3c    aiot            3         50000     vip
# 4c      새싹            4        200000    vvip

# %%
a_df = pd.read_csv('bank3_accounts.csv', index_col='a_id')
a_df
# Out:
#      password c_id  amount
# a_id
# 11a       11p   1c     100
# 12a       12p   1c     400
# 21a       21p   2c    2000
# 31a       31p   3c   10000
# 32a       32p   3c   20000
# 33a       33p   3c   20000
# 41a       41p   4c  100000
# 42a       42p   4c   50000
# 43a       43p   4c   20000
# 44a       44p   4c   30000

# %%
# self.accounts 에서 해당 계좌번호의 계좌금액에서 입금금액 추가
a_df['amount'].loc['11a'] +500
# Out:
# 600

# %%
a_id = '54a'
a_df.append({'a_id': a_id,
                            'password': None,
                                  'c_id': None,
                                  'amount': 0}, ignore_index=True)
# a_df
# Out:
# C:\Users\YUNA\AppData\Local\Temp\ipykernel_1792\3920991078.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a_df.append({'a_id': a_id,
#    password  c_id  amount a_id
# 0       11p    1c     100  NaN
# 1       12p    1c     400  NaN
# 2       21p    2c    2000  NaN
# 3       31p    3c   10000  NaN
# 4       32p    3c   20000  NaN
# 5       33p    3c   20000  NaN
# 6       41p    4c  100000  NaN
# 7       42p    4c   50000  NaN
# 8       43p    4c   20000  NaN
# 9       44p    4c   30000  NaN
# 10     None  None       0  54a

# %%
a_df.append()
# Out:
#   a_id password c_id  amount  aid
# 0  45a      11p   1c     100  45a
# 1  45a      12p   1c     400  45a
# 2  45a      21p   2c    2000  45a
# 3  45a      31p   3c   10000  45a
# 4  45a      32p   3c   20000  45a
# 5  45a      33p   3c   20000  45a
# 6  45a      41p   4c  100000  45a
# 7  45a      42p   4c   50000  45a
# 8  45a      43p   4c   20000  45a
# 9  45a      44p   4c   30000  45a

# %%
df_accounts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   a_id      10 non-null     object
#  1   password  10 non-null     object
#  2   c_id      10 non-null     object
#  3   amount    10 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 448.0+ bytes

# %%
df_accounts[['a_id', 'amount']]
# Out:
#   a_id  amount
# 0  11a     100
# 1  12a     400
# 2  21a    2000
# 3  31a   10000
# 4  32a   20000
# 5  33a   20000
# 6  41a  100000
# 7  42a   50000
# 8  43a   20000
# 9  44a   30000

# %%
df_accounts[['a_id', 'amount']][df_accounts['a_id'] == '32a']
# Out:
#   a_id  amount
# 4  32a   20000

# %%
df_accounts.loc['32a':]
# Out:
#   a_id password c_id  amount
# 4  32a      32p   3c   20000
# 5  33a      33p   3c   20000
# 6  41a      41p   4c  100000
# 7  42a      42p   4c   50000
# 8  43a      43p   4c   20000
# 9  44a      44p   4c   30000
